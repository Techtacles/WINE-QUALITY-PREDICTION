# %% [markdown]
# This dataset was gotten from https://www.kaggle.com/rajyellow46/wine-quality

# %% [markdown]
# # DESCRIPTION

# %% [markdown]
# Fixed acidity: Fixed acids include tartaric, malic, citric, and succinic acids which are found in grapes (except succinic)
# Acids are one of the fundamental properties of wine and contribute greatly to the taste of the wine, Acidity in food and drink tastes tart and zesty. Tasting acidity is also sometimes confused with alcohol. Wines with higher acidity feel lighter-bodied because they come across as “spritzy”. Reducing acids significantly might lead to wines tasting flat. If you prefer a wine that is richer and rounder, you enjoy slightly less acidity.
# <br><br>Volatile acidity: These acids are to be distilled out from the wine before completing the production process. It is primarily constituted of acetic acid though other acids like lactic, formic and butyric acids might also be present. Excess of volatile acids are undesirable and lead to unpleasant flavour.
# <br><br>Citric acid: This is one of the fixed acids which gives a wine its freshness. Usually most of it is consumed during the fermentation process and sometimes it is added separately to give the wine more freshness.
# <br><br>Residual sugar: This typically refers to the natural sugar from grapes which remains after the fermentation process stops, or is stopped.
# <br><br>Chlorides: Chloride concentration in the wine is influenced by terroir and its highest levels are found in wines coming from countries where irrigation is carried out using salty water or in areas with brackish terrains.
# <br><br>Free sulfur dioxide: This is the part of the sulphur dioxide that when added to a wine is said to be free after the remaining part binds. Winemakers will always try to get the highest proportion of free sulphur to bind. They are also known as sulfites and too much of it is undesirable and gives a pungent odour.
# Total sulfur dioxide: This is the sum total of the bound and the free sulfur dioxide. This is mainly added to kill harmful bacteria and preserve quality and freshness. There are usually legal limits for sulfur levels in wines and excess of it can even kill good yeast and give out undesirable odour.
# <br><br>Density: This can be represented as a comparison of the weight of a specific volume of wine to an equivalent volume of water. It is generally used as a measure of the conversion of sugar to alcohol.
# <br><br>pH: Also known as the potential of hydrogen, this is a numeric scale to specify the acidity or basicity the wine. Fixed acidity contributes the most towards the pH of wines. You might know, solutions with a pH less than 7 are acidic, while solutions with a pH greater than 7 are basic. With a pH of 7, pure water is neutral. Most wines have a pH between 2.9 and 3.9 and are therefore acidic.
# <br><br>Sulphates: These are mineral salts containing sulfur. Sulphates are to wine as gluten is to food. They are a regular part of the winemaking around the world and are considered essential. They are connected to the fermentation process and affects the wine aroma and flavour.
# <br><br>Alcohol: It's usually measured in % vol or alcohol by volume (ABV).
# <br><br>Quality: Wine experts graded the wine quality between 0 (very bad) and 10 (very excellent). The eventual quality score is the median of at least three evaluations made by the same wine experts.<br><br><br>

# %% [markdown]
# # FROM RESEARCH

# %% [markdown]
# Wine with low acidity will taste richer and rounder
# <br><br>A touch of volatile acidity is okay in a wine
# <br><br>ph of 3-3.4 is good in white wine while 3.3-3.6 is best for red wine
# <br><br>moderate to HIGH chloride gives the wine undesirable salty taste...so chlorides should be low
# <br><br>Dry wine contains about 10g/l of residual sugar(between 0-17g/l).Sweet wine contains about 35 gram/l and above of residual sugar......middle sweet contains between 35-120 and sweet contains 120+
# <br><br>alcohol level in wine 11-13%
# <br><br>5mg is the amount of salt or sodium in good wine(0.005)
# <br><br>Wine has density between 0.97 and 0.99
# <br><br>red wine Sulphate range from 0.05 to 0.075
#
#
#
# <br><br>The more the alcohol , the less dense the wine is
# <br>Wines with lower acidity need more sulphite
# <br>wines with PH above 3.6 are less stable so sulfites are needed more
# <br>Free sulfite dioxide is dependent on ph

# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
#Reading the data
wine=pd.read_csv("winequalityN.csv")
wine.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
wine.shape
# Out:
# (6497, 13)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
wine=pd.get_dummies(wine)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  type_red  type_white
# 0      8.8        6         0           1
# ...

# %%
wine.isnull().sum()
# Out:
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# type_red                 0
# type_white               0
# dtype: int64

# %%
wine.dropna(inplace=True)

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type_red                0
# type_white              0
# dtype: int64

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.221066     0.323744
# volatile acidity           0.221066          1.000000    -0.377512
# citric acid                0.323744         -0.377512     1.000000
# residual sugar            -0.113442         -0.196677     0.142324
# chlorides                  0.299104          0.377995     0.039412
# free sulfur dioxide       -0.283485         -0.353402     0.132271
# total sulfur dioxide      -0.330543         -0.414729     0.194398
# density                    0.459713          0.272101     0.097068
# pH                        -0.251121          0.260134    -0.327860
# sulphates                  0.301263          0.225656     0.059070
# alcohol                   -0.096190         -0.039528    -0.010056
# quality                   -0.076174         -0.266677     0.084926
# type_red                   0.488552          0.653374    -0.185892
# ...

# %%
def grade_of_wine(x):
    if x<6:
        return "Bad wine"

    else:
        return "Good wine"

# %%
wine["wine_grade"]=wine["quality"].apply(grade_of_wine)

# %%
wine.wine_grade.unique()
# Out:
# array(['Good wine', 'Bad wine'], dtype=object)

# %%
wine["quality"].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
wine["wine_grade"].value_counts()
# Out:
# Good wine    4091
# Bad wine     2372
# Name: wine_grade, dtype: int64

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.221066     0.323744
# volatile acidity           0.221066          1.000000    -0.377512
# citric acid                0.323744         -0.377512     1.000000
# residual sugar            -0.113442         -0.196677     0.142324
# chlorides                  0.299104          0.377995     0.039412
# free sulfur dioxide       -0.283485         -0.353402     0.132271
# total sulfur dioxide      -0.330543         -0.414729     0.194398
# density                    0.459713          0.272101     0.097068
# pH                        -0.251121          0.260134    -0.327860
# sulphates                  0.301263          0.225656     0.059070
# alcohol                   -0.096190         -0.039528    -0.010056
# quality                   -0.076174         -0.266677     0.084926
# type_red                   0.488552          0.653374    -0.185892
# ...

# %% [markdown]
# ### EFFECT OF FIXED ACIDITY ON WINE

# %%
# %matplotlib inline
sns.boxplot(wine["fixed acidity"])

# %% [markdown]
# We see there are some outliers in fixed acidity above 13...let's remove them

# %%
wine=wine[wine["fixed acidity"]<13]

# %%
# %matplotlib inline
plt.figure(figsize=(20,10))
sns.barplot(wine["wine_grade"],wine["fixed acidity"])
plt.ylim(0,8)
# Out:
# (0, 8)

# %% [markdown]
# We see that good wine has the lowest fixed acidity of about 7.1 ;
# <br>bad wine has the highest number of fixed acidity
# <br>This sounds logical because as quality increases, fixed acidity decreases because the wine tastes less sour.

# %%
# %matplotlib inline
sns.barplot(wine["quality"],wine["fixed acidity"])

# %%
wine[wine["wine_grade"]=="Good wine"]["fixed acidity"].value_counts()
# Out:
# 6.8     225
# 6.6     207
# 7.0     201
# 6.4     179
# 6.9     178
#        ...
# 4.2       1
# 11.0      1
# 12.7      1
# 12.3      1
# 3.9       1
# Name: fixed acidity, Length: 88, dtype: int64

# %%
wine["fixed acidity"].describe()
# Out:
# count    6439.000000
# mean        7.192289
# std         1.229917
# min         3.800000
# 25%         6.400000
# 50%         7.000000
# 75%         7.700000
# max        12.900000
# Name: fixed acidity, dtype: float64

# %%
wine[wine["wine_grade"]=="Bad wine"]["fixed acidity"].value_counts()
# Out:
# 6.8     127
# 6.4     123
# 6.6     119
# 7.2     112
# 7.6     102
#        ...
# 11.8      1
# 4.5       1
# 10.1      1
# 11.4      1
# 12.1      1
# Name: fixed acidity, Length: 84, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(wine["wine_grade"],wine["fixed acidity"])

# %% [markdown]
# ### VOLATILE ACIDITY ON GRADE OF WINE

# %%
sns.barplot(wine["wine_grade"],wine["volatile acidity"])

# %% [markdown]
# We also see here that good wines have the lowest volatile acidity .

# %%
wine[wine["wine_grade"]=="Good wine"]["volatile acidity"].value_counts()
# Out:
# 0.220    186
# 0.240    184
# 0.280    177
# 0.200    173
# 0.260    169
#         ...
# 0.425      1
# 0.850      1
# 0.895      1
# 0.365      1
# 0.910      1
# Name: volatile acidity, Length: 147, dtype: int64

# %%
wine[wine["wine_grade"]=="Bad wine"]["volatile acidity"].value_counts()
# Out:
# 0.280    108
# 0.260     86
# 0.320     83
# 0.310     83
# 0.270     82
#         ...
# 1.130      1
# 0.605      1
# 0.950      1
# 0.930      1
# 1.185      1
# Name: volatile acidity, Length: 165, dtype: int64

# %% [markdown]
# We see that bad wine has the highest percentage of volatile acidity

# %% [markdown]
# ### EFFECT OF PH ON WINE GRADE

# %% [markdown]
# From research ,pH of a good wine is between range 3 -3.4...Let's find out

# %%
sns.barplot(wine["wine_grade"],wine["pH"])
plt.ylim(0,4)
# Out:
# (0, 4)

# %%
wine[wine["wine_grade"]=="Good wine"]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6489            5.4              0.74         0.09             1.7      0.089
# 6490            6.3              0.51         0.13             2.3      0.076
# 6491            6.8              0.62         0.08             1.9      0.068
# 6494            6.3              0.51         0.13             2.3      0.076
# 6496            6.0              0.31         0.47             3.6      0.067
#
# ...

# %% [markdown]
# We see that pH is almost normalized across various categories of wine

# %% [markdown]
# ### ALCOHOL ON WINE QUALITY

# %% [markdown]
# A good wine has alcohol level between 10% -13%.Let's proove it from  our data

# %%
wine[wine["wine_grade"]=="Good wine"]["alcohol"].value_counts()
# Out:
# 11.000000    172
# 10.500000    147
# 9.500000     144
# 10.400000    133
# 10.800000    126
#             ...
# 10.750000      1
# 13.550000      1
# 9.233333       1
# 12.066667      1
# 14.050000      1
# Name: alcohol, Length: 96, dtype: int64

# %%
# %matplotlib inline
plt.figure(figsize=(15,10))
sns.barplot(wine["wine_grade"],wine["alcohol"])

# %% [markdown]
# We see that the alcohol level of good wine is about 11%,  for bad wine is about 10.17%

# %% [markdown]
# ### EFFECT OF CHLORIDES ON GRADE

# %% [markdown]
# From intuition and research, chloride level for a grade of wine is meant to be low ; otherwise it will be too salty

# %%
wine[wine["wine_grade"]=="Good wine"]["chlorides"].describe()
# Out:
# count    4075.000000
# mean        0.051071
# std         0.028508
# min         0.012000
# 25%         0.036000
# 50%         0.044000
# 75%         0.057000
# max         0.415000
# Name: chlorides, dtype: float64

# %%
sns.barplot(wine["wine_grade"],wine["chlorides"])

# %% [markdown]
# Here we see that the chloride level of good wine is the lowest i.e about 0.05 which is the same as the one from our research above.SO, we see our data is very accurate.
# <br>The chloride for average wine is the highest

# %% [markdown]
# ### EFFECT OF RESIDUAL SUGAR

# %% [markdown]
# A dry wine has residual sugar between 0-17 g/l . However, sweet wine has residual sugar 35 above...So, let us find out where to place a good wine; whether it is dry or sweet

# %%
sns.barplot(wine["wine_grade"],wine["residual sugar"])

# %%
wine[wine["wine_grade"]=="Good wine"]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6489            5.4              0.74         0.09             1.7      0.089
# 6490            6.3              0.51         0.13             2.3      0.076
# 6491            6.8              0.62         0.08             1.9      0.068
# 6494            6.3              0.51         0.13             2.3      0.076
# 6496            6.0              0.31         0.47             3.6      0.067
#
# ...

# %%
sns.lineplot(wine["wine_grade"],wine["residual sugar"])

# %% [markdown]
# We can say that good wine has lower residual sugar than bad wine

# %%
wine["residual sugar"].nlargest(10)
# Out:
# 2781    65.80
# 1653    31.60
# 1663    31.60
# 3619    26.05
# 3623    26.05
# 1608    23.50
# 4480    22.60
# 182     22.00
# 191     22.00
# 444     20.80
# Name: residual sugar, dtype: float64

# %%
wine["residual sugar"].mean()
# Out:
# 5.45224413728842

# %%
wine[wine["residual sugar"]>5.452244]["wine_grade"].value_counts()
# Out:
# Good wine    1496
# Bad wine      945
# Name: wine_grade, dtype: int64

# %% [markdown]
# We see that most good wines are above the mean; they have high values

# %% [markdown]
# ### EFFECT OF SULPHATE

# %%
sns.barplot(wine["wine_grade"],wine["sulphates"])

# %% [markdown]
# We see from thhe graph that good wines have high sulphate values and bad wines have fairly low sulphate values

# %% [markdown]
# ### EFFECT OF TOTAL SULFITE DIOXIDE ON GRADE

# %%
wine[wine["wine_grade"]=="Good wine"]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6489            5.4              0.74         0.09             1.7      0.089
# 6490            6.3              0.51         0.13             2.3      0.076
# 6491            6.8              0.62         0.08             1.9      0.068
# 6494            6.3              0.51         0.13             2.3      0.076
# 6496            6.0              0.31         0.47             3.6      0.067
#
# ...

# %%
sns.barplot(wine["wine_grade"],wine["total sulfur dioxide"])

# %% [markdown]
# Average wine has the most total sulfur dioxide

# %% [markdown]
# ### FREE SULFUR DIOXIDE

# %%
sns.barplot(wine["wine_grade"],wine["free sulfur dioxide"])

# %% [markdown]
# Good wines have the most free sulfur dioxide

# %%
wine.var()
# Out:
# fixed acidity              1.512696
# volatile acidity           0.027115
# citric acid                0.020862
# residual sugar            22.687210
# chlorides                  0.001231
# free sulfur dioxide      315.168926
# total sulfur dioxide    3183.872157
# density                    0.000009
# pH                         0.025761
# sulphates                  0.022084
# alcohol                    1.419801
# quality                    0.763710
# type_red                   0.184404
# type_white                 0.184404
# dtype: float64

# %% [markdown]
# We see here that residual sugar , free sulfur dioxide, total sulfur dioxide have high variance

# %%
sns.pairplot(wine)

# %% [markdown]
# ### FEATURE IMPORTANCES

# %%
x_feat=wine.drop(["quality","wine_grade"],axis="columns")
y_feat=wine["wine_grade"]

# %%
from sklearn.ensemble import ExtraTreesClassifier
feat = ExtraTreesClassifier()
feat.fit(x_feat,y_feat)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(feat.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
# Out:
# [0.07084842 0.1116494  0.07994285 0.07441352 0.07400784 0.08037784
#  0.08337077 0.08939814 0.07145294 0.07797091 0.17366766 0.00710294
#  0.00579677]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(feat.feature_importances_, index=x_feat.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# We see the most important features using feature importances are alcohol,volatile acidity,density,total sulfur dioxide

# %% [markdown]
# ### UNIVARIATE

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(x_feat,y_feat)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x_feat.columns)

# %%
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns

# %%
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#                    Specs       Score
# 6   total sulfur dioxide  397.203802
# 10               alcohol  138.137913
# 5    free sulfur dioxide  134.095580
# 11              type_red   68.083200
# 1       volatile acidity   36.956384
# 3         residual sugar   23.539791
# 12            type_white   21.953301
# 0          fixed acidity    6.942976
# 4              chlorides    4.720699
# 2            citric acid    2.416561

# %% [markdown]
# Here we see that the most important are (total sulfur dioxide, free sulfur dioxide,alcohol,residual sugar),type red , volatile acidity, type  white

# %% [markdown]
# ### DATA MODELLING

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# %%
wine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
# 1                 14.0                 132.0    0.994  3.3       0.49
#
#    alcohol  quality  type_red  type_white wine_grade
# 0      8.8        6         0           1  Good wine
# 1      9.5        6         0           1  Good wine

# %%
X=wine[["total sulfur dioxide","free sulfur dioxide","alcohol","residual sugar","volatile acidity","type_red","fixed acidity","type_white","pH","sulphates","citric acid","density"]]
y=wine["wine_grade"]

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=50)

# %%
scale=StandardScaler()

# %%
Xtrain=scale.fit_transform(Xtrain)
Xtest=scale.transform(Xtest)

# %%
rfc=RandomForestClassifier(random_state=85).fit(Xtrain,ytrain)
ypred=rfc.predict(Xtest)
accuracy=accuracy_score(ypred,ytest)

# %%
print(f"The accuracy of the random  forest classifier is {accuracy}")
# Out:
# The accuracy of the random  forest classifier is 0.843167701863354

# %%
mat=confusion_matrix(ytest,ypred)
mat
# Out:
# array([[363, 107],
#        [ 95, 723]], dtype=int64)

# %%
sns.heatmap(mat,annot=True , xticklabels=["Bad","Good"],yticklabels=["Bad","Good"])
plt.xlabel("Actual")
plt.ylabel("Predicted")
# Out:
# Text(33.0, 0.5, 'Predicted')

# %% [markdown]
# We see our model mislabelled bad wine as good wine 95 times
# <br> Our model mislabelled good wine as bad wine 107 times

# %%
data=pd.DataFrame({"Actual":ytest,"Predicted":ypred})

# %%
data.shape
# Out:
# (1288, 2)

# %%
data[data["Actual"]==data["Predicted"]].shape
# Out:
# (1086, 2)

# %% [markdown]
# Our model scored 1086 out of 1288 accurately

# %% [markdown]
# ### ERROR RATE

# %%
print(f"The error rate of our model is {1-accuracy}")
# Out:
# The error rate of our model is 0.156832298136646

# %%
from sklearn.metrics import recall_score

print("recall_score()            : ",  recall_score(ytest, ypred, average='micro'))
# Out:
# recall_score()            :  0.843167701863354

# %% [markdown]
# # IMBALANCED DATA

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6491            6.8             0.620         0.08             1.9      0.068
# 6492            6.2             0.600         0.08             2.0      0.090
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
def new_wine_grade(x):
    if x <5 :
        return "Bad wine"
    else:
        return "Good wine"

# %%
wine["imbalanced_wine_grade"]=wine["quality"].apply(new_wine_grade)

# %%
wine["imbalanced_wine_grade"].value_counts()
# Out:
# Good wine    6195
# Bad wine      244
# Name: imbalanced_wine_grade, dtype: int64

# %% [markdown]
# Here we see that the wine is imbalanced i.e we have about 6200 good wines and 244 bad wines

# %%
sns.lineplot(wine["imbalanced_wine_grade"],wine["residual sugar"])

# %%
sns.barplot(wine["imbalanced_wine_grade"],wine["sulphates"])

# %%
sns.barplot(wine["imbalanced_wine_grade"],wine["free sulfur dioxide"])

# %% [markdown]
# ### DATA MODELLING FOR IMBALANCED WINE GRADE

# %%
X_imbalanced=wine[["total sulfur dioxide","free sulfur dioxide","alcohol","residual sugar","volatile acidity","type_red","fixed acidity","type_white","pH","sulphates","citric acid","density"]]
y_imbalanced=wine["imbalanced_wine_grade"]

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X_imbalanced,y_imbalanced,test_size=0.2,random_state=50)

# %%
scale=StandardScaler()

# %%
Xtrain=scale.fit_transform(Xtrain)
Xtest=scale.transform(Xtest)

# %%
#Using validation, random state of 82 did very well.
rfc=RandomForestClassifier(random_state=82).fit(Xtrain,ytrain)
ypred=rfc.predict(Xtest)
accuracy_score(ypred,ytest)
# Out:
# 0.968944099378882

# %%
mat_imbalanced=confusion_matrix(ytest,ypred)

# %%
mat_imbalanced
# Out:
# array([[   5,   38],
#        [   2, 1243]], dtype=int64)

# %%
sns.heatmap(mat_imbalanced,annot=True,xticklabels=["Bad","Good"],yticklabels=["Bad","Good"])
plt.xlabel("Actual")
plt.ylabel("Predicted")
# Out:
# Text(33.0, 0.5, 'Predicted')

# %% [markdown]
# Here we see our model correctly predicted Good as Good 1243 times(True positive)
# <br>our model correctly predicted bad as bad 5 times(true negative)
# <br>our model incorrectly predicted good as bad 38 times(False positive)
# <br>Our model incorrectly predicted bad as good 2 times(False negative)

# %%
data_imbalanced=pd.DataFrame({"Actual":ytest,"Predicted":ypred})

# %%
data_imbalanced
# Out:
#          Actual  Predicted
# 433    Bad wine  Good wine
# 5265  Good wine  Good wine
# 3864  Good wine  Good wine
# 5047  Good wine  Good wine
# 3767  Good wine  Good wine
# ...         ...        ...
# 4449  Good wine  Good wine
# 2785  Good wine  Good wine
# 3227  Good wine  Good wine
# 5146  Good wine  Good wine
# 2132  Good wine  Good wine
#
# [1288 rows x 2 columns]

# %%
data_imbalanced.shape
# Out:
# (1288, 2)

# %%
data_imbalanced[data_imbalanced["Actual"]==data_imbalanced["Predicted"]].shape
# Out:
# (1248, 2)

# %% [markdown]
# Our model scored 1248 out of 1288 correctly with 40 mislabelled classifications

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# :)

# %% [markdown]
# Thank you so much for viewing my project 😊
